# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
Names = ["class", "Alcohol",
 	 "Malic acid",
 	 "Ash",
	 "Alcalinity of ash",  
 	 "Magnesium",
	 "Total phenols",
 	 "Flavanoids",
 	 "Nonflavanoid phenols",
 	 "Proanthocyanins",
	 "Color intensity",
 	 "Hue",
 	 "OD280/OD315 of diluted wines",
 	 "Proline"   ]
df = pd.read_csv("wine.data",names = Names)
df
# Out:
#      class  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0        1    14.23        1.71  2.43               15.6        127
# 1        1    13.20        1.78  2.14               11.2        100
# 2        1    13.16        2.36  2.67               18.6        101
# 3        1    14.37        1.95  2.50               16.8        113
# 4        1    13.24        2.59  2.87               21.0        118
# ..     ...      ...         ...   ...                ...        ...
# 173      3    13.71        5.65  2.45               20.5         95
# 174      3    13.40        3.91  2.48               23.0        102
# 175      3    13.27        4.28  2.26               20.0        120
# 176      3    13.17        2.59  2.37               20.0        120
# 177      3    14.13        4.10  2.74               24.5         96
#
#      Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0             2.80        3.06                  0.28             2.29
# ...

# %%
sns.boxplot(data=df,x='class',y='Alcohol',hue='class',linewidth=1)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
plt.subplot(4,3,1)
sns.boxplot(data=df,x='class',y='Proline',hue='class',linewidth=1)
plt.subplot(4,3,2)
sns.boxplot(data=df,x='class',y='Malic acid',hue='class',linewidth=1)
plt.subplot(4,3,3)
sns.boxplot(data=df,x='class',y='Ash',hue='class',linewidth=1)
plt.subplot(4,3,4)
sns.boxplot(data=df,x='class',y='Alcalinity of ash',hue='class',linewidth=1)
plt.subplot(4,3,5)
sns.boxplot(data=df,x='class',y='Magnesium',hue='class',linewidth=1)
plt.subplot(4,3,6)
sns.boxplot(data=df,x='class',y='Total phenols',hue='class',linewidth=1)
plt.subplot(4,3,7)
sns.boxplot(data=df,x='class',y='Flavanoids',hue='class',linewidth=1)
plt.subplot(4,3,8)
sns.boxplot(data=df,x='class',y='Nonflavanoid phenols',hue='class',linewidth=1)
plt.subplot(4,3,9)
sns.boxplot(data=df,x='class',y='Proanthocyanins',hue='class',linewidth=1)
plt.subplot(4,3,10)
sns.boxplot(data=df,x='class',y='Color intensity',hue='class',linewidth=1)
plt.subplot(4,3,11)
sns.boxplot(data=df,x='class',y='Hue',hue='class',linewidth=1)
plt.subplot(4,3,12)
sns.boxplot(data=df,x='class',y='OD280/OD315 of diluted wines',hue='class',linewidth=1)
plt.show()

# %% [markdown]
# Inferences :
# 1) Plot of Proline :
#         We can see that the level of the proline is very much differed in the three classes. In the first box plot we can see
#         that it is skewed towards right.We also find that there are outliers in the 2nd class and it is also left skewed.In the
#         third class it seems like the data is normaly distributed and there are no outliers in the data.
# 2) Plot of Malic Acid :
#         The data points are skewed towards right and there are more outliers in the first class.
#         There are many outliers in the 2nd class when compared to 1st class, and the data is right skewed.
#         There are no outliers in the 3rd class and seems like the data is normal.
#         The median of the three classes is completely different from the 3 class given.
# 3) Plot of Ash :
#         We can observe that there is an outlier in the 1st class of Ash. The datapoints are normal.
#         There is an outlier in the 2nd class and it is right-skewed.
#         There are no outliers in the 3rd class and the data is right-skewed.
#         We can observe that the medians of the three classes are different from each other.
# 4) Plot of Alcalinity of ash :
#         We can observe that there are the outliers in the datapoints in the first class and it is more skewed towards right.
#         The second class is right skewed and there are outliers lieing in the datapoints.
#         There are no outliers in the third class and the data is right-skewed.
#         The median of the 3 different class is not same.
# 5) Plot of Magnesium :
#         The first class is right-skewed and no outliers in the data.
#         The second class is right-skewed and there are many outliers lieing in the data.
#         The datapoints in the 3rd class is right-skewed and no outliers in the data.
#         The median of the 3 different class is not same.
# 6) Plot of Total Phenols :
#         There is only one outlier in the data and the datapoints are normal.
#         There are no outliers in the second class and the data is right-skewed.
#         There are outliers in the 3rd class and the datapoints are right-skewed.
#         The median of the 3 different class is not same.
# 7) Plot of Flavonoids :
#         The datapoints rae right-skewed and no outliers in the first class.
#         There is only one outlier in the second class and the datapoints are normal.
#         The datapoints are right-skewed and only one outlier in the third class of Flavonoids.
# 8) Plot of Nonflavanoid phenols :
#         The datapoints are left-skewed and there are outliers in the 1st class of the datapoints.
#         The datapoints are right-skewed and no outliers in the datapoints
#         There is only one outlier and the data is left-skewed.
# 9) Plot of Color intensity :
#         The datapoints rae right-skewed and one outlier in the first class.
#         There are many outliers in the data and the datapoints are normal.
#         There are no outliers in the 3rd class and the data is right-skewed.
# 10) Plot of Proanthocyanins :
#         There are few outliers in the data and the datapoints are normal.
#         There are many outliers in the data and the datapoints are left-skewed.
#         There are many outliers in the data and the datapoints are right-skewed.
# 11) Plot of Hue :
#         There are no outliers in the 1st class and the data is left-skewed.
#         There is only one outlier in the second class and the datapoints are right-skewed.
#         There are no outliers in the 3rd class and the data is right-skewed.
# 12) Plot of OD280/OD315 of diluted wines :
#         There are no outliers in the 1st class and the data is right-skewed.
#         There are no outliers in the 2nd class and the data is left-skewed.
#         There are few outliers in the data and the datapoints are right-skewed.
# 13) Plot of Alcohol :
#         There are no outliers in the 1st class and the data is right-skewed.
#         There are few outliers in the data and the datapoints are left-skewed.
#         There are no outliers in the 3rd class and the data is right-skewed.

# %%
fig, axes = plt.subplots(1,3,figsize=(8,3))
class1 = df[df['class']==1]
class2 = df[df['class']==2]
class3 = df[df['class']==3]
# plt.subplot(4,3,1)
sns.histplot(ax=axes[0],data=class1,x='Alcohol',hue='class')
sns.histplot(ax=axes[1],data=class2,x='Alcohol',hue='class')
sns.histplot(ax=axes[2],data=class3,x='Alcohol',hue='class')
plt.title('Hist Subplots for Alcohol')
plt.show()
