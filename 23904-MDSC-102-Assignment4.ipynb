# %% [markdown]
# # Reading the data files which is separated by commas and adding the feature names for the dataframe

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

Names = ["class", "Alcohol",
 	 "Malic acid",
 	 "Ash",
	 "Alcalinity of ash",  
 	 "Magnesium",
	 "Total phenols",
 	 "Flavanoids",
 	 "Nonflavanoid phenols",
 	 "Proanthocyanins",
	 "Color intensity",
 	 "Hue",
 	 "OD280/OD315 of diluted wines",
 	 "Proline"   ]
df = pd.read_csv("wine.data",names = Names)
df
# Out:
#      class  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0        1    14.23        1.71  2.43               15.6        127
# 1        1    13.20        1.78  2.14               11.2        100
# 2        1    13.16        2.36  2.67               18.6        101
# 3        1    14.37        1.95  2.50               16.8        113
# 4        1    13.24        2.59  2.87               21.0        118
# ..     ...      ...         ...   ...                ...        ...
# 173      3    13.71        5.65  2.45               20.5         95
# 174      3    13.40        3.91  2.48               23.0        102
# 175      3    13.27        4.28  2.26               20.0        120
# 176      3    13.17        2.59  2.37               20.0        120
# 177      3    14.13        4.10  2.74               24.5         96
#
#      Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0             2.80        3.06                  0.28             2.29
# ...

# %% [markdown]
# # Plotting the Hist plot for the feature class

# %%
plt.hist(df['class'])
# Out:
# (array([59.,  0.,  0.,  0.,  0., 71.,  0.,  0.,  0., 48.]),
#  array([1. , 1.2, 1.4, 1.6, 1.8, 2. , 2.2, 2.4, 2.6, 2.8, 3. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # Plotting the count plot for the features Alcohol and Ash

# %%
sns.countplot(x='class',data=df) # we give the feature name and data to the function
# Out:
# <Axes: xlabel='class', ylabel='count'>

# %%
sns.scatterplot(x='Alcohol',y='Ash',hue='class',data=df)
# Out:
# <Axes: xlabel='Alcohol', ylabel='Ash'>

# %%
sns.scatterplot?

# %%
plt.figure(figsize=(15,15))
plt.subplot(4,3,1)
sns.scatterplot(x='Alcohol',y='Ash',hue='class',data=df,palette='deep')
plt.subplot(4,3,2)
sns.scatterplot(x='Alcohol',y='Malic acid',hue='class',data=df,palette='deep')
plt.subplot(4,3,3)
sns.scatterplot(x='Alcohol',y='Alcalinity of ash',hue='class',data=df,palette='deep')
plt.subplot(4,3,4)
sns.scatterplot(x='Alcohol',y='Magnesium',hue='class',data=df,palette='deep')
plt.subplot(4,3,5)
sns.scatterplot(x='Alcohol',y='Total phenols',hue='class',data=df,palette='deep')
plt.subplot(4,3,6)
sns.scatterplot(x='Alcohol',y='Flavanoids',hue='class',data=df,palette='deep')
plt.subplot(4,3,7)
sns.scatterplot(x='Alcohol',y='Nonflavanoid phenols',hue='class',data=df,palette='deep')
plt.subplot(4,3,8)
sns.scatterplot(x='Alcohol',y='Proanthocyanins',hue='class',data=df,palette='deep')
plt.subplot(4,3,9)
sns.scatterplot(x='Alcohol',y='Color intensity',hue='class',data=df,palette='deep')
plt.subplot(4,3,10)
sns.scatterplot(x='Alcohol',y='Hue',hue='class',data=df,palette='deep')
plt.subplot(4,3,11)
sns.scatterplot(x='Alcohol',y='OD280/OD315 of diluted wines',hue='class',data=df,palette='deep')
plt.subplot(4,3,12)
sns.scatterplot(x='Alcohol',y='Proline',hue='class',data=df,palette='deep')
# Out:
# <Axes: xlabel='Alcohol', ylabel='Proline'>

# %%
INFERENCES :

1) Alcohol and Ash :
    Class 1 and class 3 have the same amount hue and class 2 is increasing from the bottom to top.Class 1 and class 3 have the strong relation
    ship and class 1 doesn't interact much with these 2 classes
    
2) Alcohol and Malic Acid :
    All the three classes form 3 different clusters and only some data points from each of these three clusters interact
    
3) Alcohol and Alcalimity of Ash :
    Data points of class 2 and class 3 interact much whereas the data points of  class 1 are not much interacting.

4) Alcohol and Magnesium :
    There are some of the ouliers in class 2 which don't interact with much of the datapoints of the class 1 and class 3

4) Alcohol and Pronthocyanins:
    class 1 and class 3 are better interaction with class hue but there are some of the outliers in the class 2
    
5) Alcohol and Total Phenols :
    These 2 classes form two different clusters and class 1 is increasing and the bothe the classes doesnot interact much with class hue

6) Alcohol and Flavonoids :
    These two also form the separate two clusters where onl;y few data points interact with the class 3
    
7) Alcohol and Non flavonoid phenols :
    As we can see that the all the classes are increasing and they interact with each otherin a good way
    
8) Alcohol and color intensity :
    we can see that class 2 doesn't interact with class 3 and class 1 interact with one or two data points of the class 3.
    
9) Alcohol and hue :
    class 1 and class 2 are not much interacting with the class 3 and seems like class 1 and class 2 are increasing.
    
10) Alcohol and OD280/OD315 of diluted wines :
    There are 3 clusters formed and only few of them interact with each other.

11) Alcohol and Proline :
    As we can see that class 1 is increasing and lest interacting with class 3.
